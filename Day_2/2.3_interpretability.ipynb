# %% [markdown]
# # Point Colab to our files

# %%
# !git clone https://github.com/icomse/5th_workshop_MachineLearning.git
import os
os.chdir('5th_workshop_MachineLearning/data')
data_dir = os.getcwd()
# Out:
# Cloning into '5th_workshop_MachineLearning'...
# remote: Enumerating objects: 82, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 82 (delta 26), reused 46 (delta 12), pack-reused 0
# Unpacking objects: 100% (82/82), 8.05 MiB | 6.54 MiB/s, done.

# %% [markdown]
# # We'll use pymatgen and matminer in this module, so we need to install them

# %%
# !pip install matminer
# Out:
# Collecting matminer
#   Downloading matminer-0.9.0-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 17.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.1 in /usr/local/lib/python3.10/dist-packages (from matminer) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from matminer) (2.27.1)
# Requirement already satisfied: pandas~=1.5 in /usr/local/lib/python3.10/dist-packages (from matminer) (1.5.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from matminer) (4.65.0)
# Collecting pymongo (from matminer)
#   Downloading pymongo-4.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (648 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 648.9/648.9 kB 40.3 MB/s eta 0:00:00
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from matminer) (0.18.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from matminer) (1.2.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from matminer) (1.11.1)
# Collecting monty (from matminer)
#   Downloading monty-2023.5.8-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 7.5 MB/s eta 0:00:00
# Collecting pymatgen (from matminer)
#   Downloading pymatgen-2023.6.28.tar.gz (9.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 86.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas~=1.5->matminer) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas~=1.5->matminer) (2022.7.1)
# Requirement already satisfied: frozendict in /usr/local/lib/python3.10/dist-packages (from pymatgen->matminer) (2.3.8)
# Requirement already satisfied: matplotlib>=1.5 in /usr/local/lib/python3.10/dist-packages (from pymatgen->matminer) (3.7.1)
# Collecting mp-api<0.34.0,>=0.27.3 (from pymatgen->matminer)
#   Downloading mp_api-0.33.3-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from pymatgen->matminer) (3.1)
# Requirement already satisfied: palettable>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from pymatgen->matminer) (3.3.3)
# Requirement already satisfied: plotly>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from pymatgen->matminer) (5.13.1)
# Collecting pybtex (from pymatgen->matminer)
#   Downloading pybtex-0.24.0-py2.py3-none-any.whl (561 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.4/561.4 kB 46.2 MB/s eta 0:00:00
# Collecting ruamel.yaml>=0.17.0 (from pymatgen->matminer)
#   Downloading ruamel.yaml-0.17.32-py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from pymatgen->matminer) (1.10.1)
# Collecting spglib>=2.0.2 (from pymatgen->matminer)
#   Downloading spglib-2.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (515 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.3/515.3 kB 37.2 MB/s eta 0:00:00
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from pymatgen->matminer) (0.8.10)
# Collecting uncertainties>=3.1.4 (from pymatgen->matminer)
#   Downloading uncertainties-3.1.7-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.4/98.4 kB 10.9 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo->matminer)
#   Downloading dnspython-2.3.0-py3-none-any.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 20.1 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->matminer) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->matminer) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->matminer) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->matminer) (3.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->matminer) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->matminer) (3.1.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->matminer) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->pymatgen->matminer) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->pymatgen->matminer) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->pymatgen->matminer) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->pymatgen->matminer) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->pymatgen->matminer) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->pymatgen->matminer) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->pymatgen->matminer) (3.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from mp-api<0.34.0,>=0.27.3->pymatgen->matminer) (67.7.2)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from mp-api<0.34.0,>=0.27.3->pymatgen->matminer) (1.0.5)
# Requirement already satisfied: typing-extensions>=3.7.4.1 in /usr/local/lib/python3.10/dist-packages (from mp-api<0.34.0,>=0.27.3->pymatgen->matminer) (4.6.3)
# Collecting emmet-core>=0.54.0 (from mp-api<0.34.0,>=0.27.3->pymatgen->matminer)
#   Downloading emmet_core-0.60.1-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.3/154.3 kB 13.1 MB/s eta 0:00:00
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.5.0->pymatgen->matminer) (8.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas~=1.5->matminer) (1.16.0)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.0->pymatgen->matminer)
#   Downloading ruamel.yaml.clib-0.2.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (485 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 33.8 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=3.01 in /usr/local/lib/python3.10/dist-packages (from pybtex->pymatgen->matminer) (6.0)
# Collecting latexcodec>=1.0.4 (from pybtex->pymatgen->matminer)
#   Downloading latexcodec-2.0.1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: pydantic<2.0,>=1.10.2 in /usr/local/lib/python3.10/dist-packages (from emmet-core>=0.54.0->mp-api<0.34.0,>=0.27.3->pymatgen->matminer) (1.10.9)
# Building wheels for collected packages: pymatgen
#   Building wheel for pymatgen (pyproject.toml) ... done
#   Created wheel for pymatgen: filename=pymatgen-2023.6.28-cp310-cp310-linux_x86_64.whl size=11261579 sha256=9863fee0e93be4fd045a0b9d27e28e9948f7a8a14ae0c02ab39435aa70933f88
#   Stored in directory: /root/.cache/pip/wheels/b7/9f/ba/a2afaf0e661656fce73e3bdf3d05fb33d1c81bff446967c48b
# Successfully built pymatgen
# Installing collected packages: uncertainties, spglib, ruamel.yaml.clib, monty, latexcodec, dnspython, ruamel.yaml, pymongo, pybtex, emmet-core, mp-api, pymatgen, matminer
# Successfully installed dnspython-2.3.0 emmet-core-0.60.1 latexcodec-2.0.1 matminer-0.9.0 monty-2023.5.8 mp-api-0.33.3 pybtex-0.24.0 pymatgen-2023.6.28 pymongo-4.4.0 ruamel.yaml-0.17.32 ruamel.yaml.clib-0.2.7 spglib-2.0.2 uncertainties-3.1.7

# %% [markdown]
# # Import some Python modules

# %%
import pandas as pd
import numpy as np
import os
import json
import matplotlib.pyplot as plt

from matminer.featurizers.composition.composite import ElementProperty
from pymatgen.core.composition import Composition

plt.style.use(os.path.join(data_dir, 'configs', 'plot_style.mplstyle'))

# %% [markdown]
# # New dataset: (Al, Ga, In)2O3 alloys
# - candidate transparent conducting oxides
# - [Kaggle competition](https://www.kaggle.com/c/nomad2018-predict-transparent-conductors)
# - [Paper on competition](https://www.nature.com/articles/s41524-019-0239-3)

# %%
df = pd.read_csv(os.path.join(data_dir, 'nomad', 'nomad_train.csv'))
df.head()
# Out:
#    id  spacegroup  number_of_total_atoms  percent_atom_al  percent_atom_ga  \
# 0   1          33                   80.0           0.6250           0.3750
# 1   2         194                   80.0           0.6250           0.3750
# 2   3         227                   40.0           0.8125           0.1875
# 3   4         167                   30.0           0.7500           0.0000
# 4   5         194                   80.0           0.0000           0.6250
#
#    percent_atom_in  lattice_vector_1_ang  lattice_vector_2_ang  \
# 0            0.000                9.9523                8.5513
# 1            0.000                6.1840                6.1838
# 2            0.000                9.7510                5.6595
# 3            0.250                5.0036                5.0034
# 4            0.375                6.6614                6.6612
#
#    lattice_vector_3_ang  lattice_angle_alpha_degree  \
# 0                9.1775                     90.0026
# 1               23.6287                     90.0186
# 2               13.9630                     90.9688
# 3               13.5318                     89.9888
# 4               24.5813                     89.9960
#
#    lattice_angle_beta_degree  lattice_angle_gamma_degree  \
# 0                    90.0023                     90.0017
# 1                    89.9980                    120.0025
# 2                    91.1228                     30.5185
# 3                    90.0119                    120.0017
# 4                    90.0006                    119.9893
#
#    formation_energy_ev_natom  bandgap_energy_ev
# 0                     0.0680             3.4387
# 1                     0.2490             2.9210
# 2                     0.1821             2.7438
# 3                     0.2172             3.3492
# 4                     0.0505             1.3793

# %% [markdown]
# # Rename some columns to make things easier

# %%
df = df.rename(columns={'spacegroup' : 'sg',
                        'number_of_total_atoms' : 'Natoms',
                        'percent_atom_al' : 'x_Al',
                        'percent_atom_ga' : 'x_Ga',
                        'percent_atom_in' : 'x_In',
                        'lattice_vector_1_ang' : 'a',
                        'lattice_vector_2_ang' : 'b',
                        'lattice_vector_3_ang' : 'c',
                        'lattice_angle_alpha_degree' : 'alpha',
                        'lattice_angle_beta_degree' : 'beta',
                        'lattice_angle_gamma_degree' : 'gamma',
                        'formation_energy_ev_natom' : 'E',
                        'bandgap_energy_ev' : 'Eg'})

# %% [markdown]
# # Compute a couple features that may be helpful

# %%
def get_volume(row):
    a, b, c, alpha, beta, gamma = row['a'], row['b'], row['c'], row['alpha'], row['beta'], row['gamma']
    alpha, beta, gamma = np.deg2rad(alpha), np.deg2rad(beta), np.deg2rad(gamma)
    return a*b*c*np.sqrt(1 - np.cos(alpha)**2 - np.cos(beta)**2 - np.cos(gamma)**2 + 2*np.cos(alpha)*np.cos(beta)*np.cos(gamma))
df['volume'] = df.apply(get_volume, axis=1)

df['atomic_density'] = df['Natoms'] / df['volume']
df.head()
# Out:
#    id   sg  Natoms    x_Al    x_Ga   x_In       a       b        c    alpha  \
# 0   1   33    80.0  0.6250  0.3750  0.000  9.9523  8.5513   9.1775  90.0026
# 1   2  194    80.0  0.6250  0.3750  0.000  6.1840  6.1838  23.6287  90.0186
# 2   3  227    40.0  0.8125  0.1875  0.000  9.7510  5.6595  13.9630  90.9688
# 3   4  167    30.0  0.7500  0.0000  0.250  5.0036  5.0034  13.5318  89.9888
# 4   5  194    80.0  0.0000  0.6250  0.375  6.6614  6.6612  24.5813  89.9960
#
#       beta     gamma       E      Eg      volume  atomic_density
# 0  90.0023   90.0017  0.0680  3.4387  781.052081        0.102426
# 1  89.9980  120.0025  0.2490  2.9210  782.500110        0.102236
# 2  91.1228   30.5185  0.1821  2.7438  391.227531        0.102242
# 3  90.0119  120.0017  0.2172  3.3492  293.377334        0.102257
# 4  90.0006  119.9893  0.0505  1.3793  944.713843        0.084682

# %% [markdown]
# # Convert the composition fractions into chemical formulas
# - this will make it easier to generate "compositional" features with `matminer`

# %%
def get_formula(row):
    elements = ['Al', 'Ga', 'In']
    columns = ['x_%s' % el for el in elements]
    mole_fractions = [row[column] for column in columns]
    data = dict(zip(elements, mole_fractions))

    for el in elements:
        orig_frac = data[el]
        data[el] = orig_frac*2

    data['O'] = 3

    formula = Composition(data).formula
    return formula

df['formula'] = df.apply(get_formula, axis=1)
df.head()
# Out:
#    id   sg  Natoms    x_Al    x_Ga   x_In       a       b        c    alpha  \
# 0   1   33    80.0  0.6250  0.3750  0.000  9.9523  8.5513   9.1775  90.0026
# 1   2  194    80.0  0.6250  0.3750  0.000  6.1840  6.1838  23.6287  90.0186
# 2   3  227    40.0  0.8125  0.1875  0.000  9.7510  5.6595  13.9630  90.9688
# 3   4  167    30.0  0.7500  0.0000  0.250  5.0036  5.0034  13.5318  89.9888
# 4   5  194    80.0  0.0000  0.6250  0.375  6.6614  6.6612  24.5813  89.9960
#
#       beta     gamma       E      Eg      volume  atomic_density  \
# 0  90.0023   90.0017  0.0680  3.4387  781.052081        0.102426
# 1  89.9980  120.0025  0.2490  2.9210  782.500110        0.102236
# 2  91.1228   30.5185  0.1821  2.7438  391.227531        0.102242
# 3  90.0119  120.0017  0.2172  3.3492  293.377334        0.102257
# 4  90.0006  119.9893  0.0505  1.3793  944.713843        0.084682
#
#               formula
# 0    Al1.25 Ga0.75 O3
# 1    Al1.25 Ga0.75 O3
# 2  Al1.625 Ga0.375 O3
# 3      Al1.5 In0.5 O3
# 4    In0.75 Ga1.25 O3

# %% [markdown]
# # Now, we'll use `matminer` to compute new features

# %%
elprop = ElementProperty.from_preset('matminer')

elprop
# Out:
# ElementProperty(data_source=<matminer.utils.data.PymatgenData object at 0x7fbd13115b40>,
#                 features=['X', 'row', 'group', 'block', 'atomic_mass',
#                           'atomic_radius', 'mendeleev_no',
#                           'electrical_resistivity', 'velocity_of_sound',
#                           'thermal_conductivity', 'melting_point',
#                           'bulk_modulus',
#                           'coefficient_of_linear_thermal_expansion'],
#                 stats=['minimum', 'maximum', 'range', 'mean', 'std_dev'])

# %% [markdown]
# ## Let's see what these look like

# %%
some_formula = 'Al2O3'
elprop.featurize(Composition(some_formula))
# Out:
# [1.61,
#  3.44,
#  1.8299999999999998,
#  2.708,
#  1.2940054095713818,
#  2,
#  3,
#  1,
#  2.4,
#  0.7071067811865476,
#  13,
#  16,
#  3,
#  14.8,
#  2.121320343559643,
#  2.0,
#  2.0,
#  0.0,
#  2.0,
#  0.0,
#  15.9994,
#  26.9815386,
#  10.9821386,
#  20.39225544,
#  7.7655446759905375,
#  0.6,
#  1.25,
#  0.65,
#  0.86,
#  0.45961940777125593,
#  80.0,
#  101.0,
#  21.0,
#  92.6,
#  14.849242404917499,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  317.5,
#  5100.0,
#  4782.5,
#  2230.5,
#  3381.7381810246634,
#  0.02658,
#  235.0,
#  234.97342,
#  94.01594800000001,
#  166.15129868059472,
#  54.8,
#  933.47,
#  878.6700000000001,
#  406.26800000000003,
#  621.3135154251837,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan]

# %% [markdown]
# # What do these numbers mean?

# %%
feature_values = elprop.featurize(Composition(some_formula))
feature_labels = elprop.feature_labels()
labels_to_values = dict(zip(feature_labels, feature_values))
labels_to_values = {k : v for i, (k, v) in enumerate(labels_to_values.items()) if v}
labels_to_values
# Out:
# {'PymatgenData minimum X': 1.61,
#  'PymatgenData maximum X': 3.44,
#  'PymatgenData range X': 1.8299999999999998,
#  'PymatgenData mean X': 2.708,
#  'PymatgenData std_dev X': 1.2940054095713818,
#  'PymatgenData minimum row': 2,
#  'PymatgenData maximum row': 3,
#  'PymatgenData range row': 1,
#  'PymatgenData mean row': 2.4,
#  'PymatgenData std_dev row': 0.7071067811865476,
#  'PymatgenData minimum group': 13,
#  'PymatgenData maximum group': 16,
#  'PymatgenData range group': 3,
#  'PymatgenData mean group': 14.8,
#  'PymatgenData std_dev group': 2.121320343559643,
#  'PymatgenData minimum block': 2.0,
#  'PymatgenData maximum block': 2.0,
#  'PymatgenData mean block': 2.0,
#  'PymatgenData minimum atomic_mass': 15.9994,
#  'PymatgenData maximum atomic_mass': 26.9815386,
#  'PymatgenData range atomic_mass': 10.9821386,
#  'PymatgenData mean atomic_mass': 20.39225544,
#  'PymatgenData std_dev atomic_mass': 7.7655446759905375,
#  'PymatgenData minimum atomic_radius': 0.6,
#  'PymatgenData maximum atomic_radius': 1.25,
#  'PymatgenData range atomic_radius': 0.65,
#  'PymatgenData mean atomic_radius': 0.86,
#  'PymatgenData std_dev atomic_radius': 0.45961940777125593,
#  'PymatgenData minimum mendeleev_no': 80.0,
#  'PymatgenData maximum mendeleev_no': 101.0,
#  'PymatgenData range mendeleev_no': 21.0,
#  'PymatgenData mean mendeleev_no': 92.6,
#  'PymatgenData std_dev mendeleev_no': 14.849242404917499,
#  'PymatgenData minimum electrical_resistivity': nan,
#  'PymatgenData maximum electrical_resistivity': nan,
#  'PymatgenData range electrical_resistivity': nan,
#  'PymatgenData mean electrical_resistivity': nan,
#  'PymatgenData std_dev electrical_resistivity': nan,
#  'PymatgenData minimum velocity_of_sound': 317.5,
#  'PymatgenData maximum velocity_of_sound': 5100.0,
#  'PymatgenData range velocity_of_sound': 4782.5,
#  'PymatgenData mean velocity_of_sound': 2230.5,
#  'PymatgenData std_dev velocity_of_sound': 3381.7381810246634,
#  'PymatgenData minimum thermal_conductivity': 0.02658,
#  'PymatgenData maximum thermal_conductivity': 235.0,
#  'PymatgenData range thermal_conductivity': 234.97342,
#  'PymatgenData mean thermal_conductivity': 94.01594800000001,
#  'PymatgenData std_dev thermal_conductivity': 166.15129868059472,
#  'PymatgenData minimum melting_point': 54.8,
#  'PymatgenData maximum melting_point': 933.47,
#  'PymatgenData range melting_point': 878.6700000000001,
#  'PymatgenData mean melting_point': 406.26800000000003,
#  'PymatgenData std_dev melting_point': 621.3135154251837,
#  'PymatgenData minimum bulk_modulus': nan,
#  'PymatgenData maximum bulk_modulus': nan,
#  'PymatgenData range bulk_modulus': nan,
#  'PymatgenData mean bulk_modulus': nan,
#  'PymatgenData std_dev bulk_modulus': nan,
#  'PymatgenData minimum coefficient_of_linear_thermal_expansion': nan,
#  'PymatgenData maximum coefficient_of_linear_thermal_expansion': nan,
#  'PymatgenData range coefficient_of_linear_thermal_expansion': nan,
#  'PymatgenData mean coefficient_of_linear_thermal_expansion': nan,
#  'PymatgenData std_dev coefficient_of_linear_thermal_expansion': nan}

# %% [markdown]
# # To save time, I generated these features for all formulas in this dataset and saved as a `.json` file

# %%
with open(os.path.join(data_dir, 'nomad', 'nomad_train_composition_features.json')) as f:
    composition_features = json.load(f)

some_formula = df.formula.values[1234]
print(some_formula)
composition_features[some_formula]
# Out:
# Al1.125 In0.25 Ga0.625 O3
# {'PymatgenData minimum X': 1.61,
#  'PymatgenData maximum X': 3.44,
#  'PymatgenData range X': 1.8299999999999998,
#  'PymatgenData mean X': 2.7415,
#  'PymatgenData std_dev X': 1.1346870321068756,
#  'PymatgenData minimum row': 2,
#  'PymatgenData maximum row': 5,
#  'PymatgenData range row': 3,
#  'PymatgenData mean row': 2.625,
#  'PymatgenData std_dev row': 1.171787241425887,
#  'PymatgenData minimum group': 13,
#  'PymatgenData maximum group': 16,
#  'PymatgenData range group': 3,
#  'PymatgenData mean group': 14.8,
#  'PymatgenData std_dev group': 1.9445260654606864,
#  'PymatgenData minimum block': 2.0,
#  'PymatgenData maximum block': 2.0,
#  'PymatgenData mean block': 2.0,
#  'PymatgenData minimum atomic_mass': 15.9994,
#  'PymatgenData maximum atomic_mass': 114.818,
#  'PymatgenData range atomic_mass': 98.8186,
#  'PymatgenData mean atomic_mass': 30.126761185,
#  'PymatgenData std_dev atomic_mass': 34.41510682280223,
#  'PymatgenData minimum atomic_radius': 0.6,
#  'PymatgenData maximum atomic_radius': 1.55,
#  'PymatgenData range atomic_radius': 0.9500000000000001,
#  'PymatgenData mean atomic_radius': 0.88125,
#  'PymatgenData std_dev atomic_radius': 0.462768639823807,
#  'PymatgenData minimum mendeleev_no': 79.0,
#  'PymatgenData maximum mendeleev_no': 101.0,
#  'PymatgenData range mendeleev_no': 22.0,
#  'PymatgenData mean mendeleev_no': 92.675,
#  'PymatgenData std_dev mendeleev_no': 13.500587555088257,
#  'PymatgenData minimum electrical_resistivity': nan,
#  'PymatgenData maximum electrical_resistivity': nan,
#  'PymatgenData range electrical_resistivity': nan,
#  'PymatgenData mean electrical_resistivity': nan,
#  'PymatgenData std_dev electrical_resistivity': nan,
#  'PymatgenData minimum velocity_of_sound': 317.5,
#  'PymatgenData maximum velocity_of_sound': 5100.0,
#  'PymatgenData range velocity_of_sound': 4782.5,
#  'PymatgenData mean velocity_of_sound': 1741.25,
#  'PymatgenData std_dev velocity_of_sound': 2610.5470095897335,
#  'PymatgenData minimum thermal_conductivity': 0.02658,
#  'PymatgenData maximum thermal_conductivity': 235.0,
#  'PymatgenData range thermal_conductivity': 234.97342,
#  'PymatgenData mean thermal_conductivity': 60.615948,
#  'PymatgenData std_dev thermal_conductivity': 126.85495272899654,
#  'PymatgenData minimum melting_point': 54.8,
#  'PymatgenData maximum melting_point': 933.47,
#  'PymatgenData range melting_point': 878.6700000000001,
#  'PymatgenData mean melting_point': 302.262,
#  'PymatgenData std_dev melting_point': 471.8796590201114,
#  'PymatgenData minimum bulk_modulus': nan,
#  'PymatgenData maximum bulk_modulus': nan,
#  'PymatgenData range bulk_modulus': nan,
#  'PymatgenData mean bulk_modulus': nan,
#  'PymatgenData std_dev bulk_modulus': nan,
#  'PymatgenData minimum coefficient_of_linear_thermal_expansion': nan,
#  'PymatgenData maximum coefficient_of_linear_thermal_expansion': nan,
#  'PymatgenData range coefficient_of_linear_thermal_expansion': nan,
#  'PymatgenData mean coefficient_of_linear_thermal_expansion': nan,
#  'PymatgenData std_dev coefficient_of_linear_thermal_expansion': nan}

# %% [markdown]
# # Let's consider only the "mean" stat for each feature

# %%
mean_features = [f for f in feature_labels if 'mean' in f]
mean_features
# Out:
# ['PymatgenData mean X',
#  'PymatgenData mean row',
#  'PymatgenData mean group',
#  'PymatgenData mean block',
#  'PymatgenData mean atomic_mass',
#  'PymatgenData mean atomic_radius',
#  'PymatgenData mean mendeleev_no',
#  'PymatgenData mean electrical_resistivity',
#  'PymatgenData mean velocity_of_sound',
#  'PymatgenData mean thermal_conductivity',
#  'PymatgenData mean melting_point',
#  'PymatgenData mean bulk_modulus',
#  'PymatgenData mean coefficient_of_linear_thermal_expansion']

# %% [markdown]
# # Add these to our `DataFrame`

# %%
def add_feature_to_df(feature, df, composition_features):
    formulas = df.formula.values
    feature_values = [composition_features[formula][feature] for formula in formulas]
    df['_'.join(feature.split(' ')[-2:])] = feature_values
    return df

for feature in mean_features:
    df = add_feature_to_df(feature, df, composition_features)

df.head()
# Out:
#    id   sg  Natoms    x_Al    x_Ga   x_In       a       b        c    alpha  \
# 0   1   33    80.0  0.6250  0.3750  0.000  9.9523  8.5513   9.1775  90.0026
# 1   2  194    80.0  0.6250  0.3750  0.000  6.1840  6.1838  23.6287  90.0186
# 2   3  227    40.0  0.8125  0.1875  0.000  9.7510  5.6595  13.9630  90.9688
# 3   4  167    30.0  0.7500  0.0000  0.250  5.0036  5.0034  13.5318  89.9888
# 4   5  194    80.0  0.0000  0.6250  0.375  6.6614  6.6612  24.5813  89.9960
#
#    ...  mean_block  mean_atomic_mass  mean_atomic_radius  mean_mendeleev_no  \
# 0  ...         2.0         26.803475             0.86750             92.750
# 1  ...         2.0         26.803475             0.86750             92.750
# 2  ...         2.0         23.597865             0.86375             92.675
# 3  ...         2.0         29.175902             0.89000             92.500
# 4  ...         2.0         44.253090             0.91750             92.700
#
#    mean_electrical_resistivity  mean_velocity_of_sound  \
# 0                          NaN                 1876.50
# 1                          NaN                 1876.50
# 2                          NaN                 2053.50
# 3                          NaN                 1842.00
# 4                          NaN                 1057.75
#
#   mean_thermal_conductivity  mean_melting_point  mean_bulk_modulus  \
# 0                 63.115948             311.684                NaN
# 1                 63.115948             311.684                NaN
# 2                 78.565948             358.976                NaN
# 3                 78.715948             355.896                NaN
# 4                 19.565948             173.070                NaN
#
#    mean_coefficient_of_linear_thermal_expansion
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# # **Hands-on**: Play with this data for a minute.
# - Our goal will be to predict the total energy, E, and band gap, Eg, using the other columns in the `DataFrame`
# - Do you notice anything we should take care of first?

# %%
# write your code here

# %% [markdown]
# # **Hands-on**: Determine which features are important for predicting `E` and `Eg`
#
# ## Guidelines:
# - Use any model you would like
# - Are the same features important for predicting both quantities?
# - Can you show why you observe any disparities in importances?

# %%
# write your code here

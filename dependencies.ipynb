# %%
# !pip install git+https://github.com/modAL-python/modAL.git
# !pip install pymatgen matminer rdkit mordred mlxtend modal shap torchani hdbscan umap-learn opentsne chemiscope skmatter ase networkx
# Out:
# Collecting git+https://github.com/modAL-python/modAL.git
#   Cloning https://github.com/modAL-python/modAL.git to /tmp/pip-req-build-ci354td9
#   Running command git clone --filter=blob:none --quiet https://github.com/modAL-python/modAL.git /tmp/pip-req-build-ci354td9
#   Resolved https://github.com/modAL-python/modAL.git to commit bba6f6fd00dbb862b1e09259b78caf6cffa2e755
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from modAL-python==0.4.2) (1.22.4)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.10/dist-packages (from modAL-python==0.4.2) (1.2.2)
# Requirement already satisfied: scipy>=0.18 in /usr/local/lib/python3.10/dist-packages (from modAL-python==0.4.2) (1.10.1)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from modAL-python==0.4.2) (1.5.3)
# Requirement already satisfied: skorch==0.9.0 in /usr/local/lib/python3.10/dist-packages (from modAL-python==0.4.2) (0.9.0)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from skorch==0.9.0->modAL-python==0.4.2) (0.8.10)
# Requirement already satisfied: tqdm>=4.14.0 in /usr/local/lib/python3.10/dist-packages (from skorch==0.9.0->modAL-python==0.4.2) (4.65.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->modAL-python==0.4.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->modAL-python==0.4.2) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->modAL-python==0.4.2) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.18->modAL-python==0.4.2) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.0->modAL-python==0.4.2) (1.16.0)
# Requirement already satisfied: pymatgen in /usr/local/lib/python3.10/dist-packages (2023.6.28)
# Requirement already satisfied: matminer in /usr/local/lib/python3.10/dist-packages (0.9.0)
# Requirement already satisfied: rdkit in /usr/local/lib/python3.10/dist-packages (2023.3.2)
# Requirement already satisfied: mordred in /usr/local/lib/python3.10/dist-packages (1.2.0)
# Requirement already satisfied: mlxtend in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: modal in /usr/local/lib/python3.10/dist-packages (0.50.2614)
# Requirement already satisfied: shap in /usr/local/lib/python3.10/dist-packages (0.42.0)
# Requirement already satisfied: torchani in /usr/local/lib/python3.10/dist-packages (2.2.3)
# Requirement already satisfied: hdbscan in /usr/local/lib/python3.10/dist-packages (0.8.30)
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.10/dist-packages (0.5.3)
# Requirement already satisfied: opentsne in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Requirement already satisfied: chemiscope in /usr/local/lib/python3.10/dist-packages (0.5.2)
# Requirement already satisfied: skmatter in /usr/local/lib/python3.10/dist-packages (0.1.4)
# Requirement already satisfied: ase in /usr/local/lib/python3.10/dist-packages (3.22.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (2.8.8)
# Requirement already satisfied: frozendict in /usr/local/lib/python3.10/dist-packages (from pymatgen) (2.3.8)
# Requirement already satisfied: matplotlib>=1.5 in /usr/local/lib/python3.10/dist-packages (from pymatgen) (3.7.1)
# Requirement already satisfied: monty>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from pymatgen) (2023.5.8)
# Requirement already satisfied: mp-api<0.34.0,>=0.27.3 in /usr/local/lib/python3.10/dist-packages (from pymatgen) (0.33.3)
# Requirement already satisfied: numpy>=1.20.1 in /usr/local/lib/python3.10/dist-packages (from pymatgen) (1.22.4)
# Requirement already satisfied: palettable>=3.1.1 in /usr/local/lib/python3.10/dist-packages (from pymatgen) (3.3.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pymatgen) (1.5.3)
# Requirement already satisfied: plotly>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from pymatgen) (5.13.1)
# Requirement already satisfied: pybtex in /usr/local/lib/python3.10/dist-packages (from pymatgen) (0.24.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pymatgen) (2.27.1)
# Requirement already satisfied: ruamel.yaml>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from pymatgen) (0.17.32)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from pymatgen) (1.10.1)
# Requirement already satisfied: spglib>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from pymatgen) (2.0.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from pymatgen) (1.11.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from pymatgen) (0.8.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from pymatgen) (4.65.0)
# Requirement already satisfied: uncertainties>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from pymatgen) (3.1.7)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.10/dist-packages (from matminer) (4.4.0)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from matminer) (0.18.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from matminer) (1.2.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (8.4.0)
# Requirement already satisfied: six==1.* in /usr/local/lib/python3.10/dist-packages (from mordred) (1.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from mlxtend) (67.7.2)
# Requirement already satisfied: modal-client==0.50.2614 in /usr/local/lib/python3.10/dist-packages (from modal) (0.50.2614)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from modal-client==0.50.2614->modal) (3.8.4)
# Requirement already satisfied: aiostream in /usr/local/lib/python3.10/dist-packages (from modal-client==0.50.2614->modal) (0.4.5)
# Requirement already satisfied: asgiref in /usr/local/lib/python3.10/dist-packages (from modal-client==0.50.2614->modal) (3.7.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from modal-client==0.50.2614->modal) (2023.5.7)
# Requirement already satisfied: click>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from modal-client==0.50.2614->modal) (8.1.3)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.10/dist-packages (from modal-client==0.50.2614->modal) (0.100.0)
# Requirement already satisfied: grpclib==0.4.3 in /usr/local/lib/python3.10/dist-packages (from modal-client==0.50.2614->modal) (0.4.3)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from modal-client==0.50.2614->modal) (6.8.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in /usr/local/lib/python3.10/dist-packages (from modal-client==0.50.2614->modal) (3.20.3)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from modal-client==0.50.2614->modal) (13.4.2)
# Requirement already satisfied: synchronicity~=0.5.3 in /usr/local/lib/python3.10/dist-packages (from modal-client==0.50.2614->modal) (0.5.3)
# Requirement already satisfied: tblib>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from modal-client==0.50.2614->modal) (2.0.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from modal-client==0.50.2614->modal) (0.10.2)
# Requirement already satisfied: typer~=0.9.0 in /usr/local/lib/python3.10/dist-packages (from modal-client==0.50.2614->modal) (0.9.0)
# Requirement already satisfied: types-certifi in /usr/local/lib/python3.10/dist-packages (from modal-client==0.50.2614->modal) (2021.10.8.3)
# Requirement already satisfied: types-toml in /usr/local/lib/python3.10/dist-packages (from modal-client==0.50.2614->modal) (0.10.8.6)
# Requirement already satisfied: watchfiles in /usr/local/lib/python3.10/dist-packages (from modal-client==0.50.2614->modal) (0.19.0)
# Requirement already satisfied: typing-extensions~=4.6.3 in /usr/local/lib/python3.10/dist-packages (from modal-client==0.50.2614->modal) (4.6.3)
# Requirement already satisfied: cloudpickle<2.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from modal-client==0.50.2614->modal) (2.0.0)
# Requirement already satisfied: h2<5,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from grpclib==0.4.3->modal-client==0.50.2614->modal) (4.1.0)
# Requirement already satisfied: multidict in /usr/local/lib/python3.10/dist-packages (from grpclib==0.4.3->modal-client==0.50.2614->modal) (6.0.4)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (23.1)
# Requirement already satisfied: slicer==0.0.7 in /usr/local/lib/python3.10/dist-packages (from shap) (0.0.7)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.56.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from torchani) (2.0.1+cu118)
# Requirement already satisfied: lark-parser in /usr/local/lib/python3.10/dist-packages (from torchani) (0.12.0)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (0.29.35)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan) (1.2.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.5.10)
# Requirement already satisfied: ipywidgets<9,>=7 in /usr/local/lib/python3.10/dist-packages (from chemiscope) (7.7.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=3.6.0->modal-client==0.50.2614->modal) (3.15.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<9,>=7->chemiscope) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<9,>=7->chemiscope) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<9,>=7->chemiscope) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<9,>=7->chemiscope) (3.6.4)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<9,>=7->chemiscope) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<9,>=7->chemiscope) (3.0.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->pymatgen) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->pymatgen) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->pymatgen) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->pymatgen) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->pymatgen) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=1.5->pymatgen) (2.8.2)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from mp-api<0.34.0,>=0.27.3->pymatgen) (1.0.5)
# Requirement already satisfied: emmet-core>=0.54.0 in /usr/local/lib/python3.10/dist-packages (from mp-api<0.34.0,>=0.27.3->pymatgen) (0.58.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.39.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pymatgen) (2022.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.5.0->pymatgen) (8.2.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->pymatgen) (1.26.16)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->pymatgen) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pymatgen) (3.4)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/lib/python3.10/dist-packages (from ruamel.yaml>=0.17.0->pymatgen) (0.2.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->matminer) (3.1.0)
# Requirement already satisfied: PyYAML>=3.01 in /usr/local/lib/python3.10/dist-packages (from pybtex->pymatgen) (6.0)
# Requirement already satisfied: latexcodec>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from pybtex->pymatgen) (2.0.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo->matminer) (2.3.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->pymatgen) (1.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->torchani) (3.12.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->torchani) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->torchani) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->torchani) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->torchani) (16.0.6)
# Requirement already satisfied: pydantic<2.0,>=1.10.2 in /usr/local/lib/python3.10/dist-packages (from emmet-core>=0.54.0->mp-api<0.34.0,>=0.27.3->pymatgen) (1.10.9)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7->chemiscope) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7->chemiscope) (6.3.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7->chemiscope) (0.18.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7->chemiscope) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7->chemiscope) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7->chemiscope) (3.0.38)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7->chemiscope) (2.14.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7->chemiscope) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7->chemiscope) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<9,>=7->chemiscope) (4.8.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=12.0.0->modal-client==0.50.2614->modal) (3.0.0)
# Requirement already satisfied: sigtools==4.0.1 in /usr/local/lib/python3.10/dist-packages (from synchronicity~=0.5.3->modal-client==0.50.2614->modal) (4.0.1)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from sigtools==4.0.1->synchronicity~=0.5.3->modal-client==0.50.2614->modal) (23.1.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (6.4.8)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->modal-client==0.50.2614->modal) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->modal-client==0.50.2614->modal) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->modal-client==0.50.2614->modal) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->modal-client==0.50.2614->modal) (1.3.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from fastapi->modal-client==0.50.2614->modal) (0.27.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->torchani) (2.1.3)
# Requirement already satisfied: anyio>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from watchfiles->modal-client==0.50.2614->modal) (3.7.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio>=3.0.0->watchfiles->modal-client==0.50.2614->modal) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio>=3.0.0->watchfiles->modal-client==0.50.2614->modal) (1.1.1)
# Requirement already satisfied: hyperframe<7,>=6.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3.1.0->grpclib==0.4.3->modal-client==0.50.2614->modal) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3.1.0->grpclib==0.4.3->modal-client==0.50.2614->modal) (4.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<9,>=7->chemiscope) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->modal-client==0.50.2614->modal) (0.1.2)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (5.3.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (5.9.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (1.5.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (0.17.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<9,>=7->chemiscope) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<9,>=7->chemiscope) (0.2.6)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (3.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (21.2.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (2.17.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (4.3.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (0.19.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<9,>=7->chemiscope) (2.21)

# %%
from openTSNE import TSNE
import ase
import chemiscope
import hdbscan
import ipywidgets
import ipykernel
import matplotlib
import matminer
import mlxtend
import modal
import mordred
import networkx
import numpy
import openpyxl
import pandas
import pymatgen
import rdkit
import seaborn
import scipy
import sklearn
import shap
import torch
import torchani
import torchvision
import umap
import xgboost
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
# cuaev not installed

# %%
from google.colab import drive
import os
drive.mount('/content/gdrive')
os.chdir('/content/gdrive/MyDrive/')
# Out:
# Mounted at /content/gdrive
